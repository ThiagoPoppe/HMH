# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')
df = df.sort_values(['tempo de execução'], ignore_index=True)
df
# Out:
#    instância  número de cidades  tempo de execução  custo da solução (VND)  \
# 0      att48                 48               0.03                   10782
# 1   berlin52                 52               0.11                    8043
# 2       pr76                 76               0.21                  121128
# 3       st70                 70               0.22                     709
# 4    kroB100                100               0.27                   25393
# 5    kroD100                100               0.28                   24721
# 6      rat99                 99               0.44                    1399
# 7    kroE100                100               0.45                   24268
# 8    kroC100                100               0.47                   22968
# 9    kroA100                100               0.50                   22489
# 10    lin105                105               0.51                   18230
# ...
