# %%
import pandas as pd

# %%
df_results = pd.read_csv('resultsVND.csv')
df_results = df_results.sort_values(['tempo de execução'])
results_index = df_results.index

df_results = df_results.reset_index(drop=True)
df_results
# Out:
#    instância  número de cidades  tempo de execução  custo da solução (VND)  \
# 0      att48                 48               0.03                   10782
# 1   berlin52                 52               0.12                    8043
# 2       pr76                 76               0.22                  121128
# 3       st70                 70               0.23                     709
# 4    kroD100                100               0.29                   24721
# 5    kroB100                100               0.34                   25393
# 6    kroC100                100               0.47                   22968
# 7      rat99                 99               0.47                    1399
# 8    kroE100                100               0.48                   24268
# 9    kroA100                100               0.52                   22489
# 10    lin105                105               0.55                   18230
# ...

# %%
df_comparison = pd.read_csv('algorithms_comparison.csv')
df_comparison = df_comparison.loc[results_index, :]

df_comparison = df_comparison.reset_index(drop=True)
df_comparison
# Out:
#    instância  número de cidades  custo da solução (NN)  \
# 0      att48                 48                  12861
# 1   berlin52                 52                   8980
# 2       pr76                 76                 153462
# 3       st70                 70                    830
# 4    kroD100                100                  26947
# 5    kroB100                100                  29158
# 6    kroC100                100                  26227
# 7      rat99                 99                   1554
# 8    kroE100                100                  27460
# 9    kroA100                100                  27807
# 10    lin105                105                  20356
# 11     pr144                144                  61652
# 12     pr136                136                 120769
# 13     pr124                124                  69297
# 14     pr152                152                  85699
# 15     pr107                107                  46680
# ...
